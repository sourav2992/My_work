# %%
import pandas as pd
import numpy as np
import math

# %%
epl_goals = pd.read_csv("D:/College_work/EPL_Challenge/epl_goals.csv")
epl_goals.round()
# Out:
#       match_id  team_id  goal_number  player1_id  player2_id goal_type
# 0        49337    10261            1     37799.0     38807.0    header
# 1        49337    10260            2     24148.0     24154.0      shot
# 2        38136     9825            1     26181.0     39297.0      shot
# 3        43276     8650            1     30853.0     30889.0  distance
# 4        40671     8654            1     23139.0     36394.0      shot
# ...        ...      ...          ...         ...         ...       ...
# 7556     45930     8659            7     25666.0     23257.0    header
# 7557     45930     8659           10    239807.0         NaN       NaN
# 7558     59737     8654            1     41232.0    195927.0    tap_in
# 7559     59737     8654            4    192899.0    155782.0    header
# 7560     59737     8456            7     37459.0     33991.0      shot
#
# [7561 rows x 6 columns]

# %%
epl_goals.head()
# Out:
#    match_id  team_id  goal_number  player1_id  player2_id goal_type
# 0     49337    10261            1     37799.0     38807.0    header
# 1     49337    10260            2     24148.0     24154.0      shot
# 2     38136     9825            1     26181.0     39297.0      shot
# 3     43276     8650            1     30853.0     30889.0  distance
# 4     40671     8654            1     23139.0     36394.0      shot

# %%
epl_players = pd.read_csv("D:/College_work/EPL_Challenge/epl_players.csv")

# %%
epl_players.head()
# Out:
#    player_id         birthday  height  weight              date  \
# 0     155782  12/15/1989 0:00  170.18   146.0    4/21/2016 0:00
# 1     155782  12/15/1989 0:00  170.18   146.0  04-07-2016 00:00
# 2     155782  12/15/1989 0:00  170.18   146.0  01-07-2016 00:00
# 3     155782  12/15/1989 0:00  170.18   146.0   12/24/2015 0:00
# 4     155782  12/15/1989 0:00  170.18   146.0   12/17/2015 0:00
#
#   preferred_foot attacking_work_rate defensive_work_rate  crossing  finishing  \
# 0           left                high              medium      80.0       53.0
# 1           left                high              medium      80.0       53.0
# 2           left                high              medium      79.0       52.0
# 3           left                high              medium      79.0       51.0
# 4           left                high              medium      79.0       51.0
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
epl_potential_shots = pd.read_csv("D:/College_work/EPL_Challenge/epl_potential_shots.csv")

# %%
epl_potential_shots.head()
# Out:
#    match_id  team_id  shot_number  player1_id     shot_type
# 0     49337    10260            1     24154.0  blocked_shot
# 1     49337    10260            2     24157.0        header
# 2     49337    10260            3     30829.0          shot
# 3     49337    10260            4     30373.0          shot
# 4     49337    10260            5     30373.0      distance

# %%
epl_teams= pd.read_csv("D:/College_work/EPL_Challenge/epl_teams.csv")

# %%
epl_teams.head()
# Out:
#    team_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0     9825  2/22/2010 0:00                66              Balanced
# 1     9825  2/22/2011 0:00                75                  Fast
# 2     9825  2/22/2012 0:00                25                  Slow
# 3     9825  9/20/2013 0:00                30                  Slow
# 4     9825  9/19/2014 0:00                59              Balanced
#
#    buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# 0                   NaN                    Little                  30
# 1                   NaN                    Little                  40
# 2                   NaN                    Little                  32
# 3                   NaN                    Little                  29
# 4                  51.0                    Normal                  26
#
#   buildUpPlayPassingClass buildUpPlayPositioningClass  chanceCreationPassing  \
# ...
